# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh-2288/batch/blob/main/nlp_lab_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, LSTM, Dense, Embedding
from tensorflow.keras.optimizers import RMSprop
from tensorflow.keras.utils import to_categorical

# Parameters
batch_size = 64
epochs = 100
latent_dim = 256
input_vocab_size = 100  # adjust based on actual vocab size
target_vocab_size = 100  # adjust based on actual vocab size

# Sample data (use your own dataset)
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# Vocabulary creation
input_texts = [pair[0] for pair in data]
target_texts = [pair[1] for pair in data]

# Create a mapping of unique tokens for both input and target sequences
input_tokens = sorted(set(" ".join(input_texts).split()))
target_tokens = sorted(set(" ".join(target_texts).split()))

input_token_index = dict([(char, i + 1) for i, char in enumerate(input_tokens)])
target_token_index = dict([(char, i + 1) for i, char in enumerate(target_tokens)])

input_vocab_size = len(input_token_index) + 1
target_vocab_size = len(target_token_index) + 1

# Encode sentences into sequences of integers
def encode_text(text, token_index, max_len):
    sequence = [token_index[word] for word in text.split() if word in token_index]
    sequence = sequence + [0] * (max_len - len(sequence))  # Pad sequences
    return sequence

# Determine maximum lengths for padding
max_encoder_seq_length = max([len(text.split()) for text in input_texts])
max_decoder_seq_length = max([len(text.split()) for text in target_texts])

# Prepare the data
encoder_input_data = np.zeros((len(input_texts), max_encoder_seq_length), dtype="int32")
decoder_input_data = np.zeros((len(target_texts), max_decoder_seq_length), dtype="int32")
decoder_target_data = np.zeros((len(target_texts), max_decoder_seq_length, target_vocab_size), dtype="float32")

for i, (input_text, target_text) in enumerate(zip(input_texts, target_texts)):
    encoder_input_data[i] = encode_text(input_text, input_token_index, max_encoder_seq_length)
    decoder_input_data[i] = encode_text(target_text, target_token_index, max_decoder_seq_length)
    for t, word in enumerate(target_text.split()):
        if word in target_token_index:
            decoder_target_data[i, t, target_token_index[word]] = 1.0
        if t > 0:
            decoder_target_data[i, t - 1, target_token_index[word]] = 1.0  # Shifts the target sequence

# Model definition
# Encoder
encoder_inputs = Input(shape=(None,))
encoder_embedding = Embedding(input_dim=input_vocab_size, output_dim=latent_dim)(encoder_inputs)
encoder_outputs, state_h, state_c = LSTM(latent_dim, return_state=True)(encoder_embedding)
encoder_states = [state_h, state_c]

# Decoder
decoder_inputs = Input(shape=(None,))
decoder_embedding = Embedding(input_dim=target_vocab_size, output_dim=latent_dim)(decoder_inputs)
decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True)
decoder_outputs, _, _ = decoder_lstm(decoder_embedding, initial_state=encoder_states)
decoder_dense = Dense(target_vocab_size, activation="softmax")
decoder_outputs = decoder_dense(decoder_outputs)

# Seq2Seq model
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)

# Compile the model
model.compile(optimizer=RMSprop(), loss="categorical_crossentropy", metrics=["accuracy"])

# Train the model
model.fit(
    [encoder_input_data, decoder_input_data],
    decoder_target_data,
    batch_size=batch_size,
    epochs=epochs,
    validation_split=0.2
)

# Inference models
# Encoder model for inference
encoder_model = Model(encoder_inputs, encoder_states)

# Decoder model for inference
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_states_inputs = [decoder_state_input_h, decoder_state_input_c]

decoder_outputs, state_h, state_c = decoder_lstm(
    decoder_embedding, initial_state=decoder_states_inputs
)
decoder_states = [state_h, state_c]
decoder_outputs = decoder_dense(decoder_outputs)

decoder_model = Model(
    [decoder_inputs] + decoder_states_inputs,
    [decoder_outputs] + decoder_states
)

# Translation function
def decode_sequence(input_seq):
    # Encode the input as state vectors.
    states_value = encoder_model.predict(input_seq)

    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1, 1))
    start_token_index = 1 if target_token_index else 0  # Default to 0 if empty
    target_seq[0, 0] = start_token_index

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
        output_tokens, h, c = decoder_model.predict([target_seq] + states_value)

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        reverse_target_token_index = dict((i, char) for char, i in target_token_index.items())
        sampled_word = reverse_target_token_index[sampled_token_index]
        decoded_sentence += ' ' + sampled_word

        # Exit condition: either hit max length or find stop character.
        if (sampled_word == '\n' or len(decoded_sentence) > max_decoder_seq_length):
            stop_condition = True

        # Update the target sequence (length 1).
        target_seq = np.zeros((1, 1))
        target_seq[0, 0] = sampled_token_index

        # Update states
        states_value = [h, c]

    return decoded_sentence.strip()

# Test the translation
test_input_seq = np.array(encode_text("hello", input_token_index, max_encoder_seq_length)).reshape(1, -1)
translated_sentence = decode_sequence(test_input_seq)
print("Translated sentence:", translated_sentence)
# Out:
# Epoch 1/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step - accuracy: 0.0000e+00 - loss: 3.3464 - val_accuracy: 0.0000e+00 - val_loss: 1.7752
# Epoch 2/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.5333 - loss: 3.2991 - val_accuracy: 0.0000e+00 - val_loss: 1.7904
# Epoch 3/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 3.2581 - val_accuracy: 0.0000e+00 - val_loss: 1.8056
# Epoch 4/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4667 - loss: 3.2164 - val_accuracy: 0.0000e+00 - val_loss: 1.8222
# Epoch 5/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 3.1705 - val_accuracy: 0.0000e+00 - val_loss: 1.8412
# Epoch 6/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 198ms/step - accuracy: 0.5333 - loss: 3.1183 - val_accuracy: 0.0000e+00 - val_loss: 1.8635
# Epoch 7/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.5333 - loss: 3.0572 - val_accuracy: 0.0000e+00 - val_loss: 1.8902
# Epoch 8/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 155ms/step - accuracy: 0.5333 - loss: 2.9849 - val_accuracy: 0.0000e+00 - val_loss: 1.9222
# Epoch 9/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.4667 - loss: 2.8985 - val_accuracy: 0.0000e+00 - val_loss: 1.9608
# Epoch 10/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 2.7950 - val_accuracy: 0.0000e+00 - val_loss: 2.0072
# Epoch 11/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 2.6717 - val_accuracy: 0.0000e+00 - val_loss: 2.0620
# Epoch 12/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.4667 - loss: 2.5271 - val_accuracy: 0.0000e+00 - val_loss: 2.1254
# Epoch 13/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4667 - loss: 2.3633 - val_accuracy: 0.0000e+00 - val_loss: 2.1970
# Epoch 14/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4667 - loss: 2.1880 - val_accuracy: 0.0000e+00 - val_loss: 2.2754
# Epoch 15/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step - accuracy: 0.4667 - loss: 2.0139 - val_accuracy: 0.0000e+00 - val_loss: 2.3587
# Epoch 16/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 110ms/step - accuracy: 0.4667 - loss: 1.8526 - val_accuracy: 0.0000e+00 - val_loss: 2.4448
# Epoch 17/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step - accuracy: 0.4667 - loss: 1.7093 - val_accuracy: 0.0000e+00 - val_loss: 2.5331
# Epoch 18/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4667 - loss: 1.5828 - val_accuracy: 0.0000e+00 - val_loss: 2.6270
# Epoch 19/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 112ms/step - accuracy: 0.4667 - loss: 1.4703 - val_accuracy: 0.0000e+00 - val_loss: 2.7335
# Epoch 20/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 109ms/step - accuracy: 0.5333 - loss: 1.3692 - val_accuracy: 0.0000e+00 - val_loss: 2.8619
# Epoch 21/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 148ms/step - accuracy: 0.5333 - loss: 1.2783 - val_accuracy: 0.0000e+00 - val_loss: 3.0249
# Epoch 22/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.5333 - loss: 1.1970 - val_accuracy: 0.0000e+00 - val_loss: 3.2383
# Epoch 23/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 136ms/step - accuracy: 0.5333 - loss: 1.1243 - val_accuracy: 0.0000e+00 - val_loss: 3.5203
# Epoch 24/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.5333 - loss: 1.0590 - val_accuracy: 0.0000e+00 - val_loss: 3.8808
# Epoch 25/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 96ms/step - accuracy: 0.5333 - loss: 0.9995 - val_accuracy: 0.0000e+00 - val_loss: 4.3072
# Epoch 26/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.9472 - val_accuracy: 0.0000e+00 - val_loss: 4.7698
# Epoch 27/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 0.9062 - val_accuracy: 0.0000e+00 - val_loss: 5.2686
# Epoch 28/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4667 - loss: 0.8768 - val_accuracy: 0.0000e+00 - val_loss: 5.8131
# Epoch 29/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.4000 - loss: 0.8679 - val_accuracy: 0.0000e+00 - val_loss: 6.3894
# Epoch 30/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step - accuracy: 0.6000 - loss: 0.9317 - val_accuracy: 0.0000e+00 - val_loss: 6.4931
# Epoch 31/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.9905 - val_accuracy: 0.0000e+00 - val_loss: 6.6812
# Epoch 32/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.6000 - loss: 0.9969 - val_accuracy: 0.0000e+00 - val_loss: 7.8755
# Epoch 33/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step - accuracy: 0.4000 - loss: 0.8551 - val_accuracy: 0.0000e+00 - val_loss: 8.1929
# Epoch 34/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 135ms/step - accuracy: 0.4000 - loss: 0.8149 - val_accuracy: 0.0000e+00 - val_loss: 8.3132
# Epoch 35/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4000 - loss: 0.8057 - val_accuracy: 0.0000e+00 - val_loss: 8.9557
# Epoch 36/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4667 - loss: 0.8454 - val_accuracy: 0.0000e+00 - val_loss: 8.5181
# Epoch 37/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.5333 - loss: 0.8526 - val_accuracy: 0.0000e+00 - val_loss: 9.2497
# Epoch 38/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step - accuracy: 0.4667 - loss: 0.8312 - val_accuracy: 0.0000e+00 - val_loss: 10.3794
# Epoch 39/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step - accuracy: 0.6000 - loss: 0.7735 - val_accuracy: 0.0000e+00 - val_loss: 10.0240
# Epoch 40/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4000 - loss: 0.8017 - val_accuracy: 0.0000e+00 - val_loss: 11.2661
# Epoch 41/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 130ms/step - accuracy: 0.6000 - loss: 0.7570 - val_accuracy: 0.0000e+00 - val_loss: 10.2488
# Epoch 42/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.4000 - loss: 0.8063 - val_accuracy: 0.0000e+00 - val_loss: 11.9629
# Epoch 43/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.5333 - loss: 0.7891 - val_accuracy: 0.0000e+00 - val_loss: 10.3918
# Epoch 44/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step - accuracy: 0.4667 - loss: 0.9203 - val_accuracy: 0.0000e+00 - val_loss: 11.8020
# Epoch 45/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 145ms/step - accuracy: 0.4000 - loss: 0.7848 - val_accuracy: 0.0000e+00 - val_loss: 12.6093
# Epoch 46/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 285ms/step - accuracy: 0.5333 - loss: 0.7469 - val_accuracy: 0.0000e+00 - val_loss: 12.0977
# Epoch 47/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 144ms/step - accuracy: 0.4000 - loss: 0.7576 - val_accuracy: 0.0000e+00 - val_loss: 13.4320
# Epoch 48/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step - accuracy: 0.6000 - loss: 0.7418 - val_accuracy: 0.0000e+00 - val_loss: 11.5420
# Epoch 49/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.8650 - val_accuracy: 0.0000e+00 - val_loss: 13.2635
# Epoch 50/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 111ms/step - accuracy: 0.4667 - loss: 0.7687 - val_accuracy: 0.0000e+00 - val_loss: 14.0183
# Epoch 51/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 86ms/step - accuracy: 0.6000 - loss: 0.8010 - val_accuracy: 0.0000e+00 - val_loss: 12.1234
# Epoch 52/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.4667 - loss: 0.8678 - val_accuracy: 0.0000e+00 - val_loss: 13.6650
# Epoch 53/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 139ms/step - accuracy: 0.6000 - loss: 0.8070 - val_accuracy: 0.0000e+00 - val_loss: 14.3913
# Epoch 54/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 88ms/step - accuracy: 0.4000 - loss: 0.7562 - val_accuracy: 0.0000e+00 - val_loss: 13.6964
# Epoch 55/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.6000 - loss: 0.7480 - val_accuracy: 0.0000e+00 - val_loss: 15.1268
# Epoch 56/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 141ms/step - accuracy: 0.4667 - loss: 0.7580 - val_accuracy: 0.0000e+00 - val_loss: 13.1959
# Epoch 57/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 179ms/step - accuracy: 0.5333 - loss: 0.7937 - val_accuracy: 0.0000e+00 - val_loss: 15.2133
# Epoch 58/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 288ms/step - accuracy: 0.5333 - loss: 0.7623 - val_accuracy: 0.0000e+00 - val_loss: 14.9090
# Epoch 59/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step - accuracy: 0.5333 - loss: 0.7627 - val_accuracy: 0.0000e+00 - val_loss: 15.8343
# Epoch 60/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 244ms/step - accuracy: 0.4000 - loss: 0.7516 - val_accuracy: 0.0000e+00 - val_loss: 14.0607
# Epoch 61/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step - accuracy: 0.5333 - loss: 0.7602 - val_accuracy: 0.0000e+00 - val_loss: 16.0548
# Epoch 62/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.4667 - loss: 0.7672 - val_accuracy: 0.0000e+00 - val_loss: 14.5980
# Epoch 63/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 0.7463 - val_accuracy: 0.0000e+00 - val_loss: 16.0849
# Epoch 64/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.7208 - val_accuracy: 0.0000e+00 - val_loss: 15.5266
# Epoch 65/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.6000 - loss: 0.7963 - val_accuracy: 0.0000e+00 - val_loss: 16.4350
# Epoch 66/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7508 - val_accuracy: 0.0000e+00 - val_loss: 15.4657
# Epoch 67/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 85ms/step - accuracy: 0.6000 - loss: 0.7590 - val_accuracy: 0.0000e+00 - val_loss: 16.5626
# Epoch 68/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 83ms/step - accuracy: 0.4000 - loss: 0.7214 - val_accuracy: 0.0000e+00 - val_loss: 15.8849
# Epoch 69/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.7536 - val_accuracy: 0.0000e+00 - val_loss: 17.0731
# Epoch 70/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4000 - loss: 0.7608 - val_accuracy: 0.0000e+00 - val_loss: 14.5184
# Epoch 71/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 99ms/step - accuracy: 0.5333 - loss: 0.7475 - val_accuracy: 0.0000e+00 - val_loss: 16.6157
# Epoch 72/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.4000 - loss: 0.7187 - val_accuracy: 0.0000e+00 - val_loss: 16.0135
# Epoch 73/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 84ms/step - accuracy: 0.5333 - loss: 0.7521 - val_accuracy: 0.0000e+00 - val_loss: 17.0469
# Epoch 74/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.4667 - loss: 0.7263 - val_accuracy: 0.0000e+00 - val_loss: 15.6522
# Epoch 75/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 140ms/step - accuracy: 0.4667 - loss: 0.7381 - val_accuracy: 0.0000e+00 - val_loss: 17.0984
# Epoch 76/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 142ms/step - accuracy: 0.4667 - loss: 0.7421 - val_accuracy: 0.0000e+00 - val_loss: 15.8134
# Epoch 77/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 137ms/step - accuracy: 0.4667 - loss: 0.7214 - val_accuracy: 0.0000e+00 - val_loss: 16.7862
# Epoch 78/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4667 - loss: 0.7740 - val_accuracy: 0.0000e+00 - val_loss: 16.5864
# Epoch 79/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 107ms/step - accuracy: 0.5333 - loss: 0.7235 - val_accuracy: 0.0000e+00 - val_loss: 16.0102
# Epoch 80/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6000 - loss: 0.7674 - val_accuracy: 0.0000e+00 - val_loss: 17.0386
# Epoch 81/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 126ms/step - accuracy: 0.4000 - loss: 0.7212 - val_accuracy: 0.0000e+00 - val_loss: 15.4492
# Epoch 82/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step - accuracy: 0.5333 - loss: 0.7242 - val_accuracy: 0.0000e+00 - val_loss: 17.0934
# Epoch 83/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 115ms/step - accuracy: 0.4000 - loss: 0.7094 - val_accuracy: 0.0000e+00 - val_loss: 15.5961
# Epoch 84/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.5333 - loss: 0.7265 - val_accuracy: 0.0000e+00 - val_loss: 17.0452
# Epoch 85/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 113ms/step - accuracy: 0.4667 - loss: 0.7078 - val_accuracy: 0.0000e+00 - val_loss: 15.8719
# Epoch 86/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 184ms/step - accuracy: 0.5333 - loss: 0.7394 - val_accuracy: 0.0000e+00 - val_loss: 16.9872
# Epoch 87/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 257ms/step - accuracy: 0.4667 - loss: 0.7075 - val_accuracy: 0.0000e+00 - val_loss: 16.0660
# Epoch 88/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 103ms/step - accuracy: 0.5333 - loss: 0.7356 - val_accuracy: 0.0000e+00 - val_loss: 16.9610
# Epoch 89/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step - accuracy: 0.4667 - loss: 0.6982 - val_accuracy: 0.0000e+00 - val_loss: 16.1884
# Epoch 90/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 124ms/step - accuracy: 0.6000 - loss: 0.7376 - val_accuracy: 0.0000e+00 - val_loss: 16.9405
# Epoch 91/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step - accuracy: 0.4667 - loss: 0.6926 - val_accuracy: 0.0000e+00 - val_loss: 16.2668
# Epoch 92/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.6000 - loss: 0.7413 - val_accuracy: 0.0000e+00 - val_loss: 16.9228
# Epoch 93/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 117ms/step - accuracy: 0.4667 - loss: 0.6888 - val_accuracy: 0.0000e+00 - val_loss: 16.3102
# Epoch 94/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 147ms/step - accuracy: 0.6000 - loss: 0.7383 - val_accuracy: 0.0000e+00 - val_loss: 16.8994
# Epoch 95/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 138ms/step - accuracy: 0.5333 - loss: 0.6850 - val_accuracy: 0.0000e+00 - val_loss: 16.3431
# Epoch 96/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 102ms/step - accuracy: 0.6000 - loss: 0.7420 - val_accuracy: 0.0000e+00 - val_loss: 16.8556
# Epoch 97/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 108ms/step - accuracy: 0.4667 - loss: 0.6833 - val_accuracy: 0.0000e+00 - val_loss: 16.3910
# Epoch 98/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 98ms/step - accuracy: 0.6000 - loss: 0.7478 - val_accuracy: 0.0000e+00 - val_loss: 16.7886
# Epoch 99/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 104ms/step - accuracy: 0.4667 - loss: 0.6833 - val_accuracy: 0.0000e+00 - val_loss: 16.4487
# Epoch 100/100
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 132ms/step - accuracy: 0.6000 - loss: 0.7442 - val_accuracy: 0.0000e+00 - val_loss: 16.6910
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 190ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 218ms/step
# Translated sentence: bonjour

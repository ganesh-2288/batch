# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh-2288/batch/blob/main/Untitled1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
lst1=[1,2,3]
array1 = np.array(lst1)
array1
# Out:
# array([1, 2, 3])

# %%
type(lst1)
# Out:
# list

# %%
array1
# Out:
# array([1, 2, 3])

# %%
import numpy as np
lst2=[4,5,6]
array2 = np.array(lst2)
array2
# Out:
# array([4, 5, 6])

# %%
type(lst2)
# Out:
# list

# %%
array2
# Out:
# array([4, 5, 6])

# %%
print("array2 multiplied by array1:",array1*array2)
print("divided by array1",array2/array1)
print("array2 raised to the power array1:",array1**array2)
# Out:
# array2 multiplied by array1: [ 4 10 18]
# divided by array1 [4.  2.5 2. ]
# array2 raised to the power array1: [  1  32 729]

# %%
#sine function
print("sine: ",np.sin(array1))
#logarithm
print("natural logarithm:",np.log(array1))
print("base-10 logarithm:",np.log10(array1))
print("base-2 logarthm:",np.log2(array1))
#exponential
print("exponential:",np.exp(array1))
# Out:
# sine:  [0.84147098 0.90929743 0.14112001]
# natural logarithm: [0.         0.69314718 1.09861229]
# base-10 logarithm: [0.         0.30103    0.47712125]
# base-2 logarthm: [0.        1.        1.5849625]
# exponential: [ 2.71828183  7.3890561  20.08553692]

# %%
people = ['praveen','vinay','sridher','cherry','trilok']
age = [21,22,23,13,21]
weight = [55,80,90,30,70]
height = [163,175,160,175,150]

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter (weight,height)
plt.title("relationship between weight and height of patients")
plt.ylabel("height in meters")
plt.xlabel("weight of patients in keys")
plt.show()

# %%
plt.figure(figsize=(12,4))
plt.title("people's weight in keys",fontsize=16,
          fontstyle='italic')

#main plot function 'bar'
plt.bar(x=people,height=weight, width=0.6,
        color='orange',edgecolor='k',alpha=0.6)
plt.xlabel("people",fontsize=15)
plt.xticks(fontsize=14,rotation=30)
plt.yticks(fontsize=14)
plt.ylabel("weight (in kgs)",fontsize=15)
# Out:
# Text(0, 0.5, 'weight (in kgs)')

# %% [markdown]
# # New section

# %% [markdown]
# <a href="https://colab.research.google.com/github/ganesh-2288/batch/blob/main/Untitled07.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Embedding, LSTM, Dense, Input
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# Sample dataset
data = [
    ("hello", "bonjour"),
    ("how are you", "comment ça va"),
    ("I am fine", "je vais bien"),
    ("what is your name", "comment tu t'appelles"),
    ("my name is", "je m'appelle"),
    ("thank you", "merci"),
    ("goodbye", "au revoir")
]

# (a) Data Preprocessing
def preprocess_data(data):
    # Split English and French sentences
    eng_texts = [pair[0] for pair in data]
    fra_texts = ['<start> ' + pair[1] + ' <end>' for pair in data]

    # Create tokenizers
    eng_tokenizer = Tokenizer()
    fra_tokenizer = Tokenizer()

    # Fit tokenizers
    eng_tokenizer.fit_on_texts(eng_texts)
    fra_tokenizer.fit_on_texts(fra_texts)

    # Convert texts to sequences
    eng_sequences = eng_tokenizer.texts_to_sequences(eng_texts)
    fra_sequences = fra_tokenizer.texts_to_sequences(fra_texts)

    # Find maximum lengths
    max_eng_len = max(len(seq) for seq in eng_sequences)
    max_fra_len = max(len(seq) for seq in fra_sequences)

    # Pad sequences
    eng_padded = pad_sequences(eng_sequences, maxlen=max_eng_len, padding='post')
    fra_padded = pad_sequences(fra_sequences, maxlen=max_fra_len, padding='post')

    return eng_padded, fra_padded, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len

# Process the data
eng_data, fra_data, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len = preprocess_data(data)

# Get vocabulary sizes
eng_vocab_size = len(eng_tokenizer.word_index) + 1
fra_vocab_size = len(fra_tokenizer.word_index) + 1

# Print shapes for debugging
print("Input shapes:")
print(f"English data shape: {eng_data.shape}")
print(f"French data shape: {fra_data.shape}")

# (b) Build Seq2Seq Model
def build_model(input_vocab, output_vocab, input_length, output_length):
    # Encoder
    encoder_inputs = Input(shape=(input_length,))
    encoder_embedding = Embedding(input_vocab, 50)(encoder_inputs)
    encoder = LSTM(100, return_state=True)
    encoder_outputs, state_h, state_c = encoder(encoder_embedding)
    encoder_states = [state_h, state_c]

    # Decoder
    decoder_inputs = Input(shape=(output_length,))
    decoder_embedding = Embedding(output_vocab, 50)(decoder_inputs)
    decoder_lstm = LSTM(100, return_sequences=True)
    decoder_outputs = decoder_lstm(decoder_embedding, initial_state=encoder_states)
    decoder_dense = Dense(output_vocab, activation='softmax')
    decoder_outputs = decoder_dense(decoder_outputs)

    # Create model
    model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
    return model

# (c) Prepare Data for Training
decoder_input_data = fra_data[:, :-1]  # Remove last token
decoder_target_data = fra_data[:, 1:]  # Remove first token

# Print shapes for debugging
print("\nTraining data shapes:")
print(f"Decoder input shape: {decoder_input_data.shape}")
print(f"Decoder target shape: {decoder_target_data.shape}")

# (d) Train the Model
model = build_model(
    eng_vocab_size,
    fra_vocab_size,
    max_eng_len,
    max_fra_len - 1
)

# Compile model
model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)

# Train model
history = model.fit(
    [eng_data, decoder_input_data],
    decoder_target_data,
    batch_size=2,
    epochs=100,
    validation_split=0.2
)

# (e) Inference Setup
class Translator:
    def __init__(self, model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len):
        self.model = model
        self.eng_tokenizer = eng_tokenizer
        self.fra_tokenizer = fra_tokenizer
        self.max_eng_len = max_eng_len
        self.max_fra_len = max_fra_len
        self.fra_index_word = {v: k for k, v in fra_tokenizer.word_index.items()}

    def translate(self, text):
        # Tokenize input text
        sequence = self.eng_tokenizer.texts_to_sequences([text])
        padded = pad_sequences(sequence, maxlen=self.max_eng_len, padding='post')

        # Initialize target sequence
        target_seq = np.zeros((1, self.max_fra_len - 1))

        # Generate translation
        prediction = self.model.predict([padded, target_seq])

        # Convert prediction to text
        output_sequence = np.argmax(prediction[0], axis=1)
        translated_text = []

        for idx in output_sequence:
            if idx != 0:
                word = self.fra_index_word.get(idx, '')
                if word and word not in ['<start>', '<end>']:
                    translated_text.append(word)

        return ' '.join(translated_text)

# (f) Translate New Sentences
translator = Translator(model, eng_tokenizer, fra_tokenizer, max_eng_len, max_fra_len)

# Test translations
test_sentences = [
    "hello",
    "thank you",
    "your name",
    "how are you"
]

print("\nTranslations:")
for sentence in test_sentences:
    translation = translator.translate(sentence)
    print(f"English: {sentence}")
    print(f"French: {translation}\n")
# Out:
# Input shapes:
# English data shape: (7, 4)
# French data shape: (7, 5)
#
# Training data shapes:
# Decoder input shape: (7, 4)
# Decoder target shape: (7, 4)
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 5s 314ms/step - accuracy: 0.1063 - loss: 2.7720 - val_accuracy: 0.3750 - val_loss: 2.7656
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.3219 - loss: 2.7543 - val_accuracy: 0.5000 - val_loss: 2.7558
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.2500 - loss: 2.7393 - val_accuracy: 0.3750 - val_loss: 2.7457
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2906 - loss: 2.7180 - val_accuracy: 0.3750 - val_loss: 2.7305
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.3219 - loss: 2.6933 - val_accuracy: 0.3750 - val_loss: 2.7107
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.2500 - loss: 2.6676 - val_accuracy: 0.2500 - val_loss: 2.6854
# Epoch 7/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.2500 - loss: 2.6196 - val_accuracy: 0.2500 - val_loss: 2.6462
# Epoch 8/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.2500 - loss: 2.5711 - val_accuracy: 0.2500 - val_loss: 2.5889
# Epoch 9/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.2500 - loss: 2.4767 - val_accuracy: 0.2500 - val_loss: 2.4923
# Epoch 10/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - accuracy: 0.2500 - loss: 2.3538 - val_accuracy: 0.2500 - val_loss: 2.3743
# Epoch 11/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - accuracy: 0.2500 - loss: 2.2274 - val_accuracy: 0.2500 - val_loss: 2.2882
# Epoch 12/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.2500 - loss: 2.0531 - val_accuracy: 0.2500 - val_loss: 2.2730
# Epoch 13/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.2500 - loss: 2.0327 - val_accuracy: 0.5000 - val_loss: 2.2712
# Epoch 14/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.3781 - loss: 2.0225 - val_accuracy: 0.5000 - val_loss: 2.2636
# Epoch 15/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3313 - loss: 2.0139 - val_accuracy: 0.5000 - val_loss: 2.2669
# Epoch 16/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 56ms/step - accuracy: 0.3000 - loss: 1.9527 - val_accuracy: 0.5000 - val_loss: 2.2828
# Epoch 17/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 53ms/step - accuracy: 0.3000 - loss: 1.9084 - val_accuracy: 0.5000 - val_loss: 2.3118
# Epoch 18/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step - accuracy: 0.4750 - loss: 1.8182 - val_accuracy: 0.5000 - val_loss: 2.3578
# Epoch 19/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.4437 - loss: 1.8191 - val_accuracy: 0.5000 - val_loss: 2.4247
# Epoch 20/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 37ms/step - accuracy: 0.4531 - loss: 1.8635 - val_accuracy: 0.5000 - val_loss: 2.5114
# Epoch 21/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5875 - loss: 1.6502 - val_accuracy: 0.5000 - val_loss: 2.6199
# Epoch 22/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.5719 - loss: 1.5033 - val_accuracy: 0.5000 - val_loss: 2.7281
# Epoch 23/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 0.5250 - loss: 1.5962 - val_accuracy: 0.3750 - val_loss: 2.8345
# Epoch 24/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - accuracy: 0.5906 - loss: 1.6155 - val_accuracy: 0.3750 - val_loss: 2.9381
# Epoch 25/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step - accuracy: 0.6687 - loss: 1.3828 - val_accuracy: 0.3750 - val_loss: 3.0509
# Epoch 26/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step - accuracy: 0.6062 - loss: 1.4679 - val_accuracy: 0.3750 - val_loss: 3.1436
# Epoch 27/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - accuracy: 0.6687 - loss: 1.2228 - val_accuracy: 0.3750 - val_loss: 3.2531
# Epoch 28/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7156 - loss: 1.0052 - val_accuracy: 0.3750 - val_loss: 3.3854
# Epoch 29/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7250 - loss: 1.0653 - val_accuracy: 0.3750 - val_loss: 3.5212
# Epoch 30/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7250 - loss: 1.0015 - val_accuracy: 0.3750 - val_loss: 3.6502
# Epoch 31/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7250 - loss: 0.8874 - val_accuracy: 0.3750 - val_loss: 3.7654
# Epoch 32/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.6875 - loss: 0.9595 - val_accuracy: 0.3750 - val_loss: 3.8530
# Epoch 33/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7906 - loss: 0.7920 - val_accuracy: 0.3750 - val_loss: 3.9238
# Epoch 34/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.7594 - loss: 0.7919 - val_accuracy: 0.3750 - val_loss: 3.9818
# Epoch 35/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8625 - loss: 0.6251 - val_accuracy: 0.3750 - val_loss: 4.0360
# Epoch 36/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.9281 - loss: 0.6261 - val_accuracy: 0.3750 - val_loss: 4.1022
# Epoch 37/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9594 - loss: 0.5077 - val_accuracy: 0.3750 - val_loss: 4.1841
# Epoch 38/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9281 - loss: 0.5287 - val_accuracy: 0.3750 - val_loss: 4.2523
# Epoch 39/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.4972 - val_accuracy: 0.3750 - val_loss: 4.3137
# Epoch 40/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.3755 - val_accuracy: 0.3750 - val_loss: 4.3775
# Epoch 41/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.3447 - val_accuracy: 0.3750 - val_loss: 4.4409
# Epoch 42/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.3481 - val_accuracy: 0.3750 - val_loss: 4.5065
# Epoch 43/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.3408 - val_accuracy: 0.3750 - val_loss: 4.5624
# Epoch 44/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.2604 - val_accuracy: 0.3750 - val_loss: 4.6066
# Epoch 45/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - accuracy: 1.0000 - loss: 0.2373 - val_accuracy: 0.3750 - val_loss: 4.6433
# Epoch 46/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.2351 - val_accuracy: 0.3750 - val_loss: 4.6742
# Epoch 47/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.2172 - val_accuracy: 0.3750 - val_loss: 4.7114
# Epoch 48/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.2221 - val_accuracy: 0.3750 - val_loss: 4.7455
# Epoch 49/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1922 - val_accuracy: 0.3750 - val_loss: 4.7591
# Epoch 50/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1793 - val_accuracy: 0.3750 - val_loss: 4.7837
# Epoch 51/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1620 - val_accuracy: 0.5000 - val_loss: 4.7977
# Epoch 52/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1443 - val_accuracy: 0.5000 - val_loss: 4.8185
# Epoch 53/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.1746 - val_accuracy: 0.5000 - val_loss: 4.8572
# Epoch 54/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1423 - val_accuracy: 0.5000 - val_loss: 4.8496
# Epoch 55/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1137 - val_accuracy: 0.3750 - val_loss: 4.8772
# Epoch 56/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.1239 - val_accuracy: 0.5000 - val_loss: 4.9082
# Epoch 57/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.1246 - val_accuracy: 0.5000 - val_loss: 4.8967
# Epoch 58/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - accuracy: 1.0000 - loss: 0.1188 - val_accuracy: 0.5000 - val_loss: 4.8859
# Epoch 59/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.1097 - val_accuracy: 0.5000 - val_loss: 4.9056
# Epoch 60/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0913 - val_accuracy: 0.5000 - val_loss: 4.9522
# Epoch 61/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0891 - val_accuracy: 0.5000 - val_loss: 4.9867
# Epoch 62/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0862 - val_accuracy: 0.5000 - val_loss: 4.9798
# Epoch 63/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0865 - val_accuracy: 0.5000 - val_loss: 4.9612
# Epoch 64/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0750 - val_accuracy: 0.5000 - val_loss: 4.9645
# Epoch 65/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0683 - val_accuracy: 0.5000 - val_loss: 4.9828
# Epoch 66/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0698 - val_accuracy: 0.5000 - val_loss: 4.9865
# Epoch 67/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0686 - val_accuracy: 0.5000 - val_loss: 5.0031
# Epoch 68/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0597 - val_accuracy: 0.5000 - val_loss: 5.0298
# Epoch 69/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0606 - val_accuracy: 0.5000 - val_loss: 5.0543
# Epoch 70/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - accuracy: 1.0000 - loss: 0.0638 - val_accuracy: 0.5000 - val_loss: 5.0525
# Epoch 71/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0577 - val_accuracy: 0.5000 - val_loss: 5.0443
# Epoch 72/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0576 - val_accuracy: 0.5000 - val_loss: 5.0405
# Epoch 73/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0504 - val_accuracy: 0.5000 - val_loss: 5.0537
# Epoch 74/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.5000 - val_loss: 5.0762
# Epoch 75/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0470 - val_accuracy: 0.5000 - val_loss: 5.0865
# Epoch 76/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0475 - val_accuracy: 0.5000 - val_loss: 5.0834
# Epoch 77/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0462 - val_accuracy: 0.5000 - val_loss: 5.0886
# Epoch 78/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0416 - val_accuracy: 0.5000 - val_loss: 5.0992
# Epoch 79/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0424 - val_accuracy: 0.5000 - val_loss: 5.1106
# Epoch 80/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0389 - val_accuracy: 0.5000 - val_loss: 5.1155
# Epoch 81/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0380 - val_accuracy: 0.5000 - val_loss: 5.1219
# Epoch 82/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0365 - val_accuracy: 0.5000 - val_loss: 5.1333
# Epoch 83/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0353 - val_accuracy: 0.5000 - val_loss: 5.1419
# Epoch 84/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 1.0000 - loss: 0.0358 - val_accuracy: 0.5000 - val_loss: 5.1470
# Epoch 85/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 1.0000 - loss: 0.0336 - val_accuracy: 0.5000 - val_loss: 5.1526
# Epoch 86/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0339 - val_accuracy: 0.5000 - val_loss: 5.1587
# Epoch 87/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0326 - val_accuracy: 0.5000 - val_loss: 5.1657
# Epoch 88/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 1.0000 - loss: 0.0321 - val_accuracy: 0.5000 - val_loss: 5.1733
# Epoch 89/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0293 - val_accuracy: 0.5000 - val_loss: 5.1816
# Epoch 90/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 1.0000 - loss: 0.0314 - val_accuracy: 0.5000 - val_loss: 5.1886
# Epoch 91/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 1.0000 - loss: 0.0287 - val_accuracy: 0.5000 - val_loss: 5.1958
# Epoch 92/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 1.0000 - loss: 0.0273 - val_accuracy: 0.5000 - val_loss: 5.2024
# Epoch 93/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0275 - val_accuracy: 0.5000 - val_loss: 5.2075
# Epoch 94/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step - accuracy: 1.0000 - loss: 0.0281 - val_accuracy: 0.5000 - val_loss: 5.2140
# Epoch 95/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0265 - val_accuracy: 0.5000 - val_loss: 5.2218
# Epoch 96/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step - accuracy: 1.0000 - loss: 0.0260 - val_accuracy: 0.5000 - val_loss: 5.2299
# Epoch 97/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.5000 - val_loss: 5.2374
# Epoch 98/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step - accuracy: 1.0000 - loss: 0.0245 - val_accuracy: 0.5000 - val_loss: 5.2442
# Epoch 99/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 29ms/step - accuracy: 1.0000 - loss: 0.0225 - val_accuracy: 0.5000 - val_loss: 5.2514
# Epoch 100/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - accuracy: 1.0000 - loss: 0.0228 - val_accuracy: 0.5000 - val_loss: 5.2588
#
# Translations:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 449ms/step
# English: hello
# French: bonjour end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 32ms/step
# English: thank you
# French: comment end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step
# English: your name
# French: comment m'appelle end
#
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 39ms/step
# English: how are you
# French: comment ça va end
